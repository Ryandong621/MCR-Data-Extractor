# %%
import re
import glob
import os
import pandas as pd
import pdfplumber
from collections import defaultdict


def extract_filing_id(text):
    """从文本中提取Filing ID"""
    match = re.search(r'FilingId=(\d+)', text)
    return match.group(1) if match else ''


def extract_metadata(pdf_path):
    """从第一页提取元数据"""
    with pdfplumber.open(pdf_path) as pdf:
        text = pdf.pages[0].extract_text()
        
        # 检查是否有编码问题
        if '(cid:' in text or not text or len(text) < 50:
            raise ValueError("PDF存在编码问题，无法读取")
        
        # 合并为单行，处理跨行标题
        text_single_line = ' '.join(text.split('\n'))
        
        # 查找标题行，兼容NMLS ID换行情况，不限制公司名格式
        title_match = re.search(r'(\d{4}\s+Q\d.*?for.*?\([\d\s]+\))', text_single_line)
        
        if not title_match:
            raise ValueError("无法匹配标题行")
        
        title_line = title_match.group(1)

        # 兼容公司名称含'(数字)'情况
        all_nmls = re.findall(r'\(([\d\s]+)\)', title_line)
        Company_NMLS_ID = all_nmls[-1] if all_nmls else None
    
    # 提取各字段
    metadata = {
        'Company NMLS ID': Company_NMLS_ID,
        'Company Name': re.search(r'for\s+(.*?)\s+\(', title_line).group(1).strip(),
        'Fiscal Year': re.search(r'(\d{4})\s+Q\d', title_line).group(1),
        'Qtr': re.search(r'\d+\s+(Q\d)', title_line).group(1),
        'Form Type': re.search(r'Q\d\s+(.*?)\s+V\d', title_line).group(1).strip(),
        'Filing ID': extract_filing_id(text)
    }
    
    return metadata


def extract_credit_lines(pdf_path):
    """从General提取CreditLine"""
    with pdfplumber.open(pdf_path) as pdf:
        text = '\n'.join([page.extract_text() for page in pdf.pages])
    
    credit_lines = []
    # CreditLine贪婪匹配，兼容负值、小数和Name of Provider含数字情况
    pattern = r'^(\d+)\s+(.+)\s+(-?[\d,]+(?:\.\d+)?)\s+(-?[\d,]+(?:\.\d+)?)\s*$'
    
    for line in text.split('\n'):
        match = re.match(pattern, line.strip())
        if match:
            credit_lines.append({
                'Record ID': int(match.group(1)),
                'Name of Provider': match.group(2).strip(),
                'Credit Limit($)': float(match.group(3).replace(',', '')),
                'Remaining Credit Period End($)': float(match.group(4).replace(',', ''))
            })
    
    return credit_lines


def extract_service_data(pdf_path):
    """从General提取Service"""
    LS_CODES = ['LS010', 'LS020', 'LS030', 'LS040', 'LS090',
                'LS100', 'LS110', 'LS190',
                'LS200', 'LS210', 'LS220', 'LS230', 'LS290']
    
    with pdfplumber.open(pdf_path) as pdf:
        full_text = '\n'.join([page.extract_text() for page in pdf.pages])
    
    service_data = {}
    
    # 提取每个LS代码的值
    for code in LS_CODES:
        # ServiceLine匹配，兼容负值情况（不兼容空值）
        pattern = rf'{code}\s+.*?\s+(-?[\d,]+(?:\.\d+)?)\s+(-?[\d,]+)\s+(-?[\d,]+(?:\.\d+)?)'
        match = re.search(pattern, full_text)
        
        if match:
            service_data[f'{code} UPB($)'] = float(match.group(1).replace(',', ''))
            service_data[f'{code} Loan Count(#)'] = int(match.group(2).replace(',', ''))
            service_data[f'{code} Avg Loan Sz($)'] = float(match.group(3).replace(',', ''))
    
    # 提取NOTE
    lines = [line.strip() for line in full_text.split('\n')]
    note_content = []
    collecting = False
    trigger_key = "NOTE Explanatory Notes - Free Text"

    # 按行查找NOTE
    for line in lines:
        if trigger_key in line:
            # 截取之后的文本
            suffix_text = line.split(trigger_key)[-1].strip()
            # 文本非空则添加到NOTE列表
            if suffix_text:
                note_content.append(suffix_text)
            collecting = True
            continue
        if 'Warnings' in line:
            collecting = False
            break
        if collecting:
            if not line:
                continue
            if line.startswith('https'): #排除页脚，查找以http开头的行
                continue
            if re.match(r'^\d{1,2}[/-]\d{1,2}[/-]\d{2,4}', line): # 排除页眉，查找以日期开头的行
                continue
            note_content.append(line)
    
    service_data['NOTE'] = ' '.join(note_content).strip() if note_content else ''
    
    return service_data


def extract_fc_data(pdf_path, field_list):
    """
    从FC提取财务数据
    
    思路：
    1. 从field_list中提取字段代码，统计每个代码对应几个字段
    2. 查找PDF中该字段代码的行
    3. 从后向前匹配N个数值（N=字段数量）
    4. 按顺序分配给对应的字段
    """
    
    # 去掉NOTE字段和文本字段，按字段代码分组
    code_to_fields = defaultdict(list)
    text_fields = ['A230J']  # 文本字段列表
    
    for field in field_list:
        if field.endswith('NOTE'):
            continue
        
        # 在第一个空格处截取，提取字段代码
        parts = field.split(' ', 1)
        if parts:
            code = parts[0]
            # 跳过文本字段
            if code in text_fields:
                continue
            code_to_fields[code].append(field)
    
    fc_data = {}
    
    # 提取文本
    with pdfplumber.open(pdf_path) as pdf:
        full_text = '\n'.join([page.extract_text() for page in pdf.pages])
    
    # 对每个字段代码，从后向前匹配数值
    for code, fields in code_to_fields.items():
        expected_count = len(fields)  # 需要匹配的数值数量
        
        # 查找该字段代码的行
        pattern = rf'^{code}\s+.*?$'
        match = re.search(pattern, full_text, re.MULTILINE) # 多行模式匹配
        
        if not match:
            continue
        
        line = match.group(0)
        
        # 提取所有数值
        all_numbers = re.findall(r'-?(?:\d+,)*\d+(?:\.\d+)?', line)
        
        # 从后向前取expected_count个数值
        values = all_numbers[-expected_count:] if len(all_numbers) >= expected_count else all_numbers
        
        # 按顺序分配给对应的字段
        for i, field in enumerate(fields):
            if i < len(values):
                value_str = values[i].replace(',', '')
                fc_data[field] = float(value_str)
    
    # 提取NOTE
    lines = [line.strip() for line in full_text.split('\n')]
    
    # 提取FCNOTE
    note_content = []
    collecting = False
    trigger_key = "FCNOTE Explanatory Notes - Free Text" # 定义触发字段
    
    for line in lines:
        if trigger_key in line:
            suffix_text = line.split(trigger_key)[-1].strip() # 截取触发字段后文本
            if suffix_text:
                note_content.append(suffix_text)
            collecting = True
            continue

        if collecting:           
            if 'Warnings' in line: # 匹配到终止词停止
                collecting = False
                break
            if not line:
                continue
            if line.startswith('https'): # 排除页脚
                continue
            if re.match(r'^\d{1,2}[/-]\d{1,2}[/-]\d{2,4}', line): # 排除页眉
                continue
            note_content.append(line)
    
    fc_data['FCNOTE'] = ' '.join(note_content).strip() if note_content else ''

    # 提取A230J
    note_content = []
    collecting = False
    trigger_key = "A230J Explanation of Amounts in 'Other Assets Other'" # 定义触发字段
    
    for line in lines:
        if trigger_key in line:
            suffix_text = line.split(trigger_key)[-1].strip() # 截取触发字段后文本
            if suffix_text:
                note_content.append(suffix_text)
            collecting = True
            continue
 
        if collecting:
            if 'Schedule B' in line: # 匹配到终止词停止
                collecting = False
                break
            if not line:
                continue
            if line.startswith('https'): # 排除页脚
                continue
            if re.match(r'^\d{1,2}[/-]\d{1,2}[/-]\d{2,4}', line): # 排除页眉
                continue
            note_content.append(line)
    
    fc_data['A230J Explanation'] = ' '.join(note_content).strip() if note_content else ''
    
    # 提取其他NOTE字段
    note_field_mapping = {
        'A60AHNOTE': 'A060AH',
        'A60AINOTE': 'A060AI',
        'A230GNOTE': 'A230G',
        'A230HNOTE': 'A230H',
        'B350NNOTE': 'B350N'
    }

    # 为每个NOTE字段定义其后续字段的标识
    note_stop_patterns = {
        'A060AH': r'A060AI\s+MEMO',
        'A060AI': r'Schedule\s+A-090',
        'A230G': r'A230H\s+Other\s+Assets\s+Other',
        'A230H': r'A230T\s+Total\s+Other\s+Assets',
        'B350N': r'B350T\s+Balance\s+at\s+End\s+of\s+Period'
    }
    
    for csv_field, pdf_code in note_field_mapping.items():
        trigger_key = f"{pdf_code} Explanatory Note - Free Text"
        
        note_content = []
        collecting = False
        
        for line in lines:
            if trigger_key in line:
                suffix_text = line.split(trigger_key)[-1].strip()
                if suffix_text:
                    note_content.append(suffix_text)
                collecting = True
                continue
            
            if collecting:
                # 停止条件1: Schedule
                if 'Schedule' in line:
                    break

                # 停止条件2: 特定的下一个字段
                if pdf_code in note_stop_patterns:
                    stop_pattern = note_stop_patterns[pdf_code]
                    if re.search(stop_pattern, line):
                        break

                else:
                    # 停止条件3: 匹配到其他字段代码（兜底，若NOTE中存在其它字段代码可能导致异常）
                    field_match = re.match(r'^([A-Z]{1,2}\d{3}[A-Z]{0,2})\s', line)
                    if field_match:
                        matched_code = field_match.group(1)
                        # 排除匹配到本身，提高稳健性
                        if matched_code != pdf_code:
                            break
                
                if not line:
                    continue
                if line.startswith('https'):
                    continue
                if re.match(r'^\d{1,2}[/-]\d{1,2}[/-]\d{2,4}', line):
                    continue
                
                note_content.append(line)
        
        fc_data[csv_field] = ' '.join(note_content).strip() if note_content else ''
        
    return fc_data



def process_pdfs(pdf_folder='CR', sample_fc_path='CR_Test/FC.csv', output_folder='.'):
    """
    处理PDF并生成CSV
    
    pdf_folder：提取文件夹地址
    sample_fc_path：示例FC.csv
    """
    
    print("=" * 60)
    print("PDF2CSV")
    print("=" * 60)
    
    # 1. 根据文件名查找PDF文件
    print("\n[1/5] 扫描PDF文件...")
    general_pattern = os.path.join(pdf_folder, '*General.pdf')
    fc_pattern = os.path.join(pdf_folder, '*FC.pdf')
    
    general_files = glob.glob(general_pattern)
    fc_files = glob.glob(fc_pattern)
    
    print(f"  找到 {len(general_files)} 个General文件")
    print(f"  找到 {len(fc_files)} 个FC文件")
    
    # 2. 加载FC字段列表
    print("\n[2/5] 加载FC字段配置...")
    sample_fc = pd.read_csv(sample_fc_path, nrows=0)
    fc_field_list = [col for col in sample_fc.columns 
                     if col not in ['Company NMLS ID', 'Company Name', 'Fiscal Year', 
                                    'Qtr', 'Form Type', 'Filing ID']]
    print(f"  FC字段数量: {len(fc_field_list)}")
    
    # 3. 处理General文件
    print("\n[3/5] 处理General文件...")
    credit_line_records = []
    service_records = []
    skipped_files = []
    
    for i, general_file in enumerate(general_files, 1):
        print(f"  [{i}/{len(general_files)}] {os.path.basename(general_file)}", end='') # 打印当前处理进度+文件名
        
        try:
            # 提取数据
            metadata = extract_metadata(general_file)
            credit_lines = extract_credit_lines(general_file)
            service_data = extract_service_data(general_file)
            
            for cl in credit_lines: # 遍历当前文件全部CreditLine，合并元数据
                credit_line_records.append({**metadata, **cl})
            
            service_records.append({**metadata, **service_data})
            
            print(" ✓")
            
        except Exception as e:
            print(f" ✗ 跳过")
            print(f"      原因: {str(e)}")
            skipped_files.append((general_file, str(e)))
    
    # 4. 处理FC文件
    print(f"\n[4/5] 处理FC文件...")
    fc_records = []
    
    for i, fc_file in enumerate(fc_files, 1):
        print(f"  [{i}/{len(fc_files)}] {os.path.basename(fc_file)}", end='')
        
        try:
            # 提取数据
            metadata = extract_metadata(fc_file)
            fc_data = extract_fc_data(fc_file, fc_field_list)
            fc_records.append({**metadata, **fc_data})
            
            print(" ✓")
            
        except Exception as e:
            print(f" ✗ 跳过")
            print(f"      原因: {str(e)}")
            skipped_files.append((fc_file, str(e)))
    
    # 5. 生成CSV文件
    print(f"\n[5/5] 生成CSV文件...")
    
    if credit_line_records:
        df_credit = pd.DataFrame(credit_line_records)
        df_credit = df_credit.drop_duplicates(
            subset=['Company NMLS ID', 'Filing ID', 'Record ID', 'Name of Provider', 'Credit Limit($)', 'Remaining Credit Period End($)'], 
            keep='first'
        )
        df_credit.to_csv(os.path.join(output_folder, 'CreditLine_output.csv'), index=False)
    print(f"  ✓ CreditLine_output.csv ({len(df_credit)} 行)")
    
    if service_records:
        df_service = pd.DataFrame(service_records)
        df_service = df_service.drop_duplicates(
            subset=['Company NMLS ID', 'Filing ID'], 
            keep='first'
        )
        df_service.to_csv(os.path.join(output_folder, 'Service_output.csv'), index=False)
    print(f"  ✓ Service_output.csv ({len(df_service)} 行)")
    
    if fc_records:
        df_fc = pd.DataFrame(fc_records)
        df_fc = df_fc.drop_duplicates(
            subset=['Company NMLS ID', 'Filing ID'], 
            keep='first'
        )
        df_fc.to_csv(os.path.join(output_folder, 'FC_output.csv'), index=False)
    print(f"  ✓ FC_output.csv ({len(df_fc)} 行)")
    
    # 统计信息
    print("\n" + "=" * 60)
    print("处理完成！")
    print("=" * 60)
    
    total_files = len(general_files) + len(fc_files)
    success_files = total_files - len(skipped_files)
    
    print(f"成功处理: {success_files} / {total_files} 个文件")
    print(f"  - General: {len(service_records)} / {len(general_files)}")
    print(f"  - FC: {len(fc_records)} / {len(fc_files)}")
    
    if skipped_files:
        print(f"\n⚠️  跳过 {len(skipped_files)} 个文件:")
        for file, error in skipped_files:
            print(f"  - {os.path.basename(file)}")
            print(f"    原因: {error}")
        
        # 保存跳过的文件列表
        skipped_df = pd.DataFrame(skipped_files, columns=['File Path', 'Error'])
        skipped_output = os.path.join(output_folder, 'skipped_files.csv')
        skipped_df.to_csv(skipped_output, index=False)
        print(f"\n跳过文件列表已保存: {skipped_output}")
    else:
        print("\n✓ 所有文件处理成功！")
    
    return df_credit, df_service, df_fc, skipped_files

df_credit, df_service, df_fc, skipped_files = process_pdfs()
# Out:
# ============================================================
# PDF2CSV
# ============================================================
#
# [1/5] 扫描PDF文件...
#   找到 370 个General文件
#   找到 111 个FC文件
#
# [2/5] 加载FC字段配置...
#   FC字段数量: 730
#
# [3/5] 处理General文件...
#   [1/370] Aurora Financial, LLC Q1 General.pdf ✓
#   [2/370] American Heritage Capital, LP Q1 General.pdf ✓
#   [3/370] American First Lending Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [4/370] Adair Financial Services, LLC Q1 General.pdf ✓
#   [5/370] American Advisors Group_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [6/370] Academy Mortgage Corporation Q1 General.pdf ✓
#   [7/370] Complete Payment Recovery Services, Inc. Q1 General.pdf ✓
#   [8/370] City First Mortgage Services, L.L.C. Q1 General.pdf ✓
#   [9/370] CTC Mortgage Services, LLC Q1 General.pdf ✓
#   [10/370] Choice Lending Corp_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [11/370] Change Lending, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [12/370] Agiant Realty Services Corporation Q1 General.pdf ✓
#   [13/370] Chelgren and Associates, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [14/370] Bainbridge Lending Group, LLC Q1 General.pdf ✓
#   [15/370] CrossCountry Mortgage, LLC Q1 General.pdf ✓
#   [16/370] Credit Control, LLC Q1 General.pdf ✓
#   [17/370] BM REAL ESTATE SERVICES, INC. Q1 General.pdf ✓
#   [18/370] American Broker Services, Inc_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [19/370] Caliber Home Loans, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [20/370] Amcap Mortgage, Ltd._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [21/370] Automatic Funds Transfer Services, Inc. Q1 General.pdf ✓
#   [22/370] Amerisave Mortgage Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [23/370] AmWest Funding Corp. Q1 General.pdf ✓
#   [24/370] Crosspoint Financial, Inc. Q1 General.pdf ✓
#   [25/370] C & E Financial Group, Inc. Q1 General.pdf ✓
#   [26/370] BLINCLOANS, LLC Q1 General.pdf ✓
#   [27/370] CUW Solutions, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [28/370] ACME FINANCE COMPANY.INC. Q1 General.pdf ✓
#   [29/370] Caliver Beach Mortgage, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [30/370] Campos Financial Corp._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [31/370] Chelgren and Associates, Inc. Q1 General.pdf ✓
#   [32/370] Aalfa Mortgage, LLC Q1 General.pdf ✓
#   [33/370] 1st Nationwide Mortgage Corporation-Q1 General.pdf ✓
#   [34/370] American Pacific Mortgage Corporation Q1 General.pdf ✓
#   [35/370] AmeriCredit Financial Services, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [36/370] Archstone Home Mortgage, LLC Q1 General.pdf ✓
#   [37/370] CommonBond Lending, LLC Q1 General.pdf ✓
#   [38/370] Capital M Lending, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [39/370] Caliver Beach Mortgage, LLC Q1 General.pdf ✓
#   [40/370] Assent Mortgage, LLC Q1 General.pdf ✓
#   [41/370] AJB SERVICES CORP. Q1 General.pdf ✓
#   [42/370] Cascade Mortgage, Inc. Q1 General.pdf ✓
#   [43/370] Chicago Financial Services, Inc. Q1 General.pdf ✓
#   [44/370] American Portfolio Mortgage Corporation Q1 General.pdf ✓
#   [45/370] CREEKSIDE MORTGAGE INCORPORATED Q1 General.pdf ✓
#   [46/370] BMG LoansAtWork, LLC Q1 General.pdf ✓
#   [47/370] Affirm Loan Services LLC Q1 General.pdf ✓
#   [48/370] ALL SQUARE MORTGAGE INC. Q1 General.pdf ✓
#   [49/370] Cleveland Street Mortgage, LLC Q1 General.pdf ✓
#   [50/370] C2 Financial Corporation Q1 General.pdf ✓
#   [51/370] California Premier Services, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [52/370] Bay-Valley Mortgage Group Q1 General.pdf ✓
#   [53/370] American Finance House LARIBA Q1 General.pdf ✓
#   [54/370] AmNet ESOP Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [55/370] AccessOne MedCard, Inc. Q1 General.pdf ✓
#   [56/370] Angel Oak Home Loans LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [57/370] Cousins, Elizabeth Anne Q1 General.pdf ✓
#   [58/370] Cascade Northern Mortgage Inc_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [59/370] Borba Investments, Inc. Q1 General.pdf ✓
#   [60/370] Chelsea Investment Group, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [61/370] CityLight Financial, Inc. Q1 General.pdf ✓
#   [62/370] Crestline Funding Corporation Q1 General.pdf ✓
#   [63/370] Cascade Residential Mortgage, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [64/370] Certain Lending, Inc. Q1 General.pdf ✓
#   [65/370] AMERIQUEST FUNDING, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [66/370] Atlantic Bay Mortgage Group, L.L.C. Q1 General.pdf ✓
#   [67/370] Alaska USA Mortgage Company, LLC Q1 General.pdf ✓
#   [68/370] Apex Mortgage, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [69/370] All Western Mortgage, Inc. Q1 General.pdf ✓
#   [70/370] Associated Mortgage Group, Inc. Q1 General.pdf ✓
#   [71/370] American Wholesale Loans LLC Q1 General.pdf ✓
#   [72/370] CityLight Financial, Inc. Q1-General.pdf ✓
#   [73/370] Bay Equity LLC Q1 General.pdf ✓
#   [74/370] Amos Financial LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [75/370] Cherry Creek Mortgage, LLC Q1 General.pdf ✓
#   [76/370] Clear Mortgage Capital, Inc. Q1 General.pdf ✓
#   [77/370] American Heritage Capital, LP_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [78/370] Chattel Funding, LLC Q1 General.pdf ✓
#   [79/370] 1ST 2ND MORTGAGE COMPANY OF N.J., INC. Q1 General.pdf ✓
#   [80/370] All Coast Lending Inc. Q1 General.pdf ✓
#   [81/370] Avenu, LLC Q1 General.pdf ✓
#   [82/370] CORONA MORTGAGE, LLC Q1 General.pdf ✓
#   [83/370] credit9, Inc. Q1 General.pdf ✓
#   [84/370] Commission Access Resources, LLC Q1 General.pdf ✓
#   [85/370] Archstone Home Mortgage, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [86/370] Castle Mortgage Corporation Q1 General.pdf ✓
#   [87/370] Approved Mortgage, Inc. Q1 General.pdf ✓
#   [88/370] America Mortgage, L.L.C. Q1 General.pdf ✓
#   [89/370] American Neighborhood Mortgage Acceptance Company LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [90/370] Arvest Central Mortgage Company Q1 General.pdf ✓
#   [91/370] Button Finance, Inc. Q1 General.pdf ✓
#   [92/370] Aurora Financial Group, Inc. Q1 General.pdf ✓
#   [93/370] American Finance House LARIBA_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [94/370] 1st Rate Home Mortgage, Inc. Q1 General.pdf ✓
#   [95/370] CountryPlace Mortgage, Ltd. Q1 General.pdf ✓
#   [96/370] AmRes Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [97/370] Assurance Processing, LLC Q1 General.pdf ✓
#   [98/370] Community Loan Servicing, LLC Q1 General.pdf ✓
#   [99/370] AMERICAN MORTGAGE INC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [100/370] All Tech Mortgage Inc. Q1 General.pdf ✓
#   [101/370] Colten Mortgage, LLC Q1-General.pdf ✓
#   [102/370] Climb Investco, LLC Q1 General.pdf ✓
#   [103/370] American Internet Mortgage, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [104/370] Cornerstone First Mortgage, Inc. Q1 General.pdf ✓
#   [105/370] Compass Mortgage, Inc. Q1 General.pdf ✓
#   [106/370] Chelsea Investment Group, LLC Q1 General.pdf ✓
#   [107/370] Coastal Pacific Lending Inc. Q1 General.pdf ✓
#   [108/370] Compu-Link Corporation Q1 General.pdf ✓
#   [109/370] Avelloe Mortgage Corporation Q1 General.pdf ✓
#   [110/370] AMERICAN MORTGAGE INC  Q1 General.pdf ✓
#   [111/370] Cognizant Mortgage Services Corporation Q1 General.pdf ✓
#   [112/370] Cornerstone Home Lending, Inc. Q1 General.pdf ✓
#   [113/370] BoardRE Inc. Q1 General.pdf ✓
#   [114/370] American Wholesale Loans LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [115/370] Casa Financial Services, Inc Q1 General.pdf ✓
#   [116/370] CGB Agri Financial Services, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [117/370] Catlin Capital, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [118/370] Central Mortgage Funding, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [119/370] Canopy Mortgage, LLC Q1 General.pdf ✓
#   [120/370] Adaptive Mortgage Solutions Inc. Q1 General.pdf ✓
#   [121/370] Celebrity Home Loans, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [122/370] Allied International Credit Corp., (US) Q1 General.pdf ✓
#   [123/370] Cascade Northern Mortgage Inc Q1 General.pdf ✓
#   [124/370] Ark-La-Tex Financial Services, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [125/370] America Home Mortgage Corporation, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [126/370] Belay Mortgage Group, Inc. Q1 General.pdf ✓
#   [127/370] American Financing Corporation Q1 General.pdf ✓
#   [128/370] American Mortgage Corporation, Inc. Q1 General.pdf ✓
#   [129/370] AEGEAN FINANCIAL Q1 General.pdf ✓
#   [130/370] Bayview Residential Brokerage Q1 General.pdf ✓
#   [131/370] Colten Mortgage, LLC Q1 General.pdf ✓
#   [132/370] 1st Nationwide Mortgage Corporation Q1 General.pdf ✓
#   [133/370] Citywide Home Loans, LLC Q1 General.pdf ✓
#   [134/370] Central Coast Lending, Inc_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [135/370] Citimortgage, Inc. Q1 General.pdf ✓
#   [136/370] American Intermutual Agency, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [137/370] 55 Places Mortgage, LLC Q1 General.pdf ✓
#   [138/370] Aalfa Mortgage, LLC-Q1 General.pdf ✓
#   [139/370] Cardinal Financial Company, Limited Partnership Q1 General.pdf ✓
#   [140/370] American Select Funding Inc. Q1 General.pdf ✓
#   [141/370] Allied Servicing Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [142/370] Crescent Mortgage Company Q1 General.pdf ✓
#   [143/370] Breeze Funding Inc. Q1 General.pdf ✓
#   [144/370] Angel Oak Mortgage Solutions LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [145/370] Altisource Fulfillment Operations, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [146/370] Cascade Home Sales, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [147/370] Accelerate Mortgage, LLC Q1 General.pdf ✓
#   [148/370] Allied Servicing Corporation Q1 General.pdf ✓
#   [149/370] Amerifirst Financial, Inc. Q1 General.pdf ✓
#   [150/370] Calculated Risk Analytics LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [151/370] Altisource Fulfillment Operations, Inc. Q1 General.pdf ✓
#   [152/370] Ark-La-Tex Financial Services, LLC Q1 General.pdf ✓
#   [153/370] American Financing Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [154/370] Alliance Capital Partners, Corp Q1 General.pdf ✓
#   [155/370] Cherry Creek Mortgage, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [156/370] Black Diamond Financial LLC Q1 General.pdf ✓
#   [157/370] AmeriHome Mortgage Company, LLC Q1 General.pdf ✓
#   [158/370] AMERIQUEST FUNDING, LLC Q1 General.pdf ✓
#   [159/370] BestWay Lending Inc, Q1 General.pdf ✓
#   [160/370] Allied Mortgage Group, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [161/370] Arc Home LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [162/370] Chaos Home Loans LLC Q1 General.pdf ✓
#   [163/370] Cascade Lending Group LLC Q1 General.pdf ✓
#   [164/370] Broker Solutions, Inc. Q1 General.pdf ✓
#   [165/370] Craft3 Q1 General.pdf ✓
#   [166/370] Amcap Mortgage, Ltd. Q1 General.pdf ✓
#   [167/370] Coastal Capital Funding Inc. Q1 General.pdf ✓
#   [168/370] Castle & Cooke Mortgage, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [169/370] Catalyst Mortgage_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [170/370] Allied Mortgage Group, Inc. Q1 General.pdf ✓
#   [171/370] Cascade Premier Mortgage, LLC Q1 General.pdf ✓
#   [172/370] Cascade Equity Group Inc Q1 General.pdf ✓
#   [173/370] Catalyst Mortgage Q1 General.pdf ✓
#   [174/370] American Pacific Mortgage Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [175/370] Celebrity Home Loans, LLC Q1 General.pdf ✓
#   [176/370] Beltway Capital, LLC Q1 General.pdf ✓
#   [177/370] Amerifirst Financial, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [178/370] American Prime Lending, Inc. Q1 General.pdf ✓
#   [179/370] Campos Financial Corp. Q1 General.pdf ✓
#   [180/370] Barrett Financial Group, L.L.C. Q1 General.pdf ✓
#   [181/370] Budget Mortgage Corp. Q1 General.pdf ✓
#   [182/370] AmeriHome Mortgage Company, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [183/370] CU Home Mortgage Solutions, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [184/370] All Credit Considered Mortgage, Inc. Q1 General.pdf ✓
#   [185/370] CEL Lending LLC Q1 General.pdf ✓
#   [186/370] CU Home Mortgage Solutions, LLC Q1 General.pdf ✓
#   [187/370] Change Lending, LLC Q1 General.pdf ✓
#   [188/370] Avenue One Capital Inc Q1 General.pdf ✓
#   [189/370] American Broker Services, Inc Q1 General.pdf ✓
#   [190/370] Cascade Premier Mortgage, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [191/370] Benchmark Lending, L.L.C. Q1 General.pdf ✓
#   [192/370] A & B Mortgage, Inc Q1 General.pdf ✓
#   [193/370] Arete Mortgage NW, LLC Q1 General.pdf ✓
#   [194/370] Best Mortgage, Inc. Q1 General.pdf ✓
#   [195/370] Balanced Processing Solutions Inc Q1 General.pdf ✓
#   [196/370] All Reverse Mortgage, Inc. Q1 General.pdf ✓
#   [197/370] Beam Lending, LLC Q1 General.pdf ✓
#   [198/370] 1st Reliant Home Loans, Inc. Q1 General.pdf ✓
#   [199/370] Clift Enterprises Inc. Q1 General.pdf ✓
#   [200/370] Creative Retirement Planning, Inc. Q1 General.pdf ✓
#   [201/370] BowHattan Holdings, Inc. Q1 General.pdf ✓
#   [202/370] AmWest Funding Corp._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [203/370] Affinity Mortgage, L.L.C. Q1 General.pdf ✓
#   [204/370] Churchill Mortgage Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [205/370] American Portfolio Mortgage Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [206/370] BEELINE MORTGAGE, LLC Q1 General.pdf ✓
#   [207/370] Bills.com, LLC Q1 General.pdf ✓
#   [208/370] Community Mortgage Funding, LLC Q1 General.pdf ✓
#   [209/370] AmRes Corporation Q1 General.pdf ✓
#   [210/370] A1 Residential Mortgage, Inc. Q1 General.pdf ✓
#   [211/370] AA Home Loans, LLC Q1 General.pdf ✓
#   [212/370] Chu & Associates, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [213/370] American Financial Network, Inc. Q1 General.pdf ✓
#   [214/370] AmeriCredit Financial Services, Inc. Q1 General.pdf ✓
#   [215/370] CentralBanc Mortgage Corporation Q1 General.pdf ✓
#   [216/370] Capital M Lending, LLC Q1 General.pdf ✓
#   [217/370] Castle Mortgage Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [218/370] Anderson, Erick B. Q1 General.pdf ✓
#   [219/370] CITADEL SERVICING CORPORATION Q1 General.pdf ✓
#   [220/370] American Heritage Lending, LLC Q1 General.pdf ✓
#   [221/370] Bankrate, LLC Q1 General.pdf ✓
#   [222/370] American Prime Lending, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [223/370] Blue Sky Financial, LLC Q1 General.pdf ✓
#   [224/370] Caliber Home Loans, Inc. Q1 General.pdf ✓
#   [225/370] Aspire Resources Inc. Q1 General.pdf ✓
#   [226/370] Belem Servicing LLC Q1 General.pdf ✓
#   [227/370] AmeriFirst Home Improvement Finance, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [228/370] American Heritage Lending, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [229/370] Blue Brick Financial LLC Q1 General.pdf ✓
#   [230/370] Cascade Equity Group Inc_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [231/370] Credit Concepts of Washington LLC Q1 General.pdf ✓
#   [232/370] Constant Investments, Inc. Q1 General.pdf ✓
#   [233/370] Arc Home LLC Q1 General.pdf ✓
#   [234/370] Button Finance, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [235/370] Berlind Corporation Q1 General.pdf ✓
#   [236/370] Cascade Valley Mortgage LLC Q1 General.pdf ✓
#   [237/370] 21st Mortgage Corporation Q1 General.pdf ✓
#   [238/370] Budget Mortgage Corp._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [239/370] American Mortgage and Insurance Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [240/370] CHA Mortgage Company, Inc. Q1 General.pdf ✓
#   [241/370] CMC Funding, Inc. Q1 General.pdf ✓
#   [242/370] Cognition Lending Corporation Q1 General.pdf ✓
#   [243/370] Bridgelock Capital Q1 General.pdf ✓
#   [244/370] American Interbanc Mortgage, LLC._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [245/370] CalCon Mutual Mortgage LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [246/370] CUW Solutions, LLC Q1 General.pdf ✓
#   [247/370] Angel Oak Home Loans LLC Q1 General.pdf ✓
#   [248/370] Aslan Home Lending Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [249/370] AdvantageFirst Lending Inc. Q1 General.pdf ✓
#   [250/370] Altamont Mortgage Funding, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [251/370] American Nationwide Mortgage Company, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [252/370] Apex Mortgage, LLC Q1 General.pdf ✓
#   [253/370] American Advisors Group Q1 General.pdf ✓
#   [254/370] All Island Mortgage & Funding Corporation Q1 General.pdf ✓
#   [255/370] Cascade Valley Mortgage LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [256/370] BKCO Mortgage, LLC Q1 General.pdf ✓
#   [257/370] Blueleaf Lending, LLC Q2 General.pdf ✓
#   [258/370] Broker Solutions, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [259/370] CEL Lending LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [260/370] BLECHMAN FINANCIAL GROUP, INC. Q1 General.pdf ✓
#   [261/370] American Nationwide Mortgage Company, Inc. Q1 General.pdf ✓
#   [262/370] AmeriNational Community Services, LLC Q1 General.pdf ✓
#   [263/370] Central Source Mortgage Banking Inc. Q1 General.pdf ✓
#   [264/370] BlockFi Lending LLC Q1 General.pdf ✓
#   [265/370] Credence Funding Corporation Q1 General.pdf ✓
#   [266/370] Axia Financial, LLC Q1 General.pdf ✓
#   [267/370] CarsDirect Mortgage Services, Inc. Q1 General.pdf ✓
#   [268/370] Adcom Group Inc Q1 General.pdf ✓
#   [269/370] Aslan Home Lending Corporation Q1 General.pdf ✓
#   [270/370] Best Finance Capital, Inc. Q1 General.pdf ✓
#   [271/370] Bayshore Mortgage Funding, LLC Q1 General.pdf ✓
#   [272/370] American Mortgage and Insurance Inc. Q1 General.pdf ✓
#   [273/370] CIS Financial Services, Inc. Q1 General.pdf ✓
#   [274/370] Access Capital Group, Inc. Q1 General.pdf ✓
#   [275/370] Blue Square Mortgage LLC Q1 General.pdf ✓
#   [276/370] Assurance Financial Group, L.L.C. Q1 General.pdf ✓
#   [277/370] American First Lending Corporation Q1 General.pdf ✓
#   [278/370] Anderson, Erick B._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [279/370] Contour Mortgage Corporation Q1 General.pdf ✓
#   [280/370] Advantage Mortgage, Inc. Q1 General.pdf ✓
#   [281/370] Credit Karma Mortgage, Inc. Q1 General.pdf ✓
#   [282/370] Borrow Smart Mortgage, Inc. Q1 General.pdf ✓
#   [283/370] 5th Street Capital, Inc. Q1 General.pdf ✓
#   [284/370] Cuervo, Michael Craig_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [285/370] America Home Mortgage Corporation, Inc. Q1 General.pdf ✓
#   [286/370] Amos Financial LLC Q1 General.pdf ✓
#   [287/370] Agape Mortgages, Inc. Q1 General.pdf ✓
#   [288/370] Casa Financial Services, Inc_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [289/370] Chattel Funding, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [290/370] California Mortgage Advisors, Inc. Q1 General.pdf ✓
#   [291/370] AmericaWest Financial, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [292/370] CentralBanc Mortgage Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [293/370] Bamboo Mortgage Inc. Q1 General.pdf ✓
#   [294/370] C & E Financial Group, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [295/370] Chicago Financial Services, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [296/370] Churchill Mortgage Corporation Q1 General.pdf ✓
#   [297/370] Arvest Central Mortgage Company_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [298/370] Arcus Lending Inc Q1 General.pdf ✓
#   [299/370] Cardinal Financial Company, Limited Partnership_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [300/370] Arete Mortgage NW, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [301/370] Asset Financial Center Inc. Q1 General.pdf ✓
#   [302/370] Arcus Lending Inc_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [303/370] American Internet Mortgage, Inc. Q1 General.pdf ✓
#   [304/370] CMG Mortgage, Inc. Q1 General.pdf ✓
#   [305/370] Central Group Mortgage LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [306/370] Afterpay US Services, LLC Q1 General.pdf ✓
#   [307/370] BALLARD MORTGAGE COMPANY Q1 General.pdf ✓
#   [308/370] ALAMEDA MORTGAGE CORPORATION Q1 General.pdf ✓
#   [309/370] Carrington Mortgage Services, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [310/370] Banner Financial Services, Inc. Q1 General.pdf ✓
#   [311/370] Calculated Risk Analytics LLC Q1 General.pdf ✓
#   [312/370] Creek and Ocean Mortgage LLC Q1 General.pdf ✓
#   [313/370] C BURKE ENTERPRISES INC. Q1 General.pdf ✓
#   [314/370] College Ave Student Loan Servicing, LLC Q1 General.pdf ✓
#   [315/370] AmeriFirst Home Improvement Finance, LLC Q1 General.pdf ✓
#   [316/370] Cooper Mortgage, Inc. Q1 General.pdf ✓
#   [317/370] Castle & Cooke Mortgage, LLC Q1 General.pdf ✓
#   [318/370] Blueleaf Lending, LLC Q1 General.pdf ✓
#   [319/370] Bellwether Lending, Inc Q1 General.pdf ✓
#   [320/370] Cascade Home Sales, Inc. Q1 General.pdf ✓
#   [321/370] ACMC FINANCIAL CORP Q1 General.pdf ✓
#   [322/370] 21st Mortgage Corporation-Q1 General.pdf ✓
#   [323/370] Avant of Washington, LLC Q1 General.pdf ✓
#   [324/370] Buenaventura Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [325/370] America Mortgage, L.L.C._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [326/370] Cuervo, Michael Craig Q1 General.pdf ✓
#   [327/370] ATHAS CAPITAL GROUP, INC. Q1 General.pdf ✓
#   [328/370] Amerisave Mortgage Corporation Q1 General.pdf ✓
#   [329/370] City Lending Inc Q1 General.pdf ✓
#   [330/370] C2 Financial Corporation_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [331/370] Cascade Residential Mortgage, LLC Q1 General.pdf ✓
#   [332/370] Angel Oak Mortgage Solutions LLC Q1 General.pdf ✓
#   [333/370] CalCon Mutual Mortgage LLC Q1 General.pdf ✓
#   [334/370] Capital Alliance, LLC Q1 General.pdf ✓
#   [335/370] Better Mortgage Corporation Q1 General.pdf ✓
#   [336/370] Cascade Lending Group LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [337/370] Catlin Capital, Inc. Q1 General.pdf ✓
#   [338/370] Certain Lending, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [339/370] Credit Union Mortgage Association, Inc. Q1 General.pdf ✓
#   [340/370] Capstone Direct, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [341/370] California Mortgage Advisors, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [342/370] Assurance Financial Group, L.L.C.Q1 General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [343/370] Clear Choice Mortgage, LLC Q1 General.pdf ✓
#   [344/370] Best Capital Funding Q1 General.pdf ✓
#   [345/370] Activus Corporation Q1 General.pdf ✓
#   [346/370] AHP Servicing LLC Q1 General.pdf ✓
#   [347/370] BP Financial Group LLC Q1 General.pdf ✓
#   [348/370] Central Mortgage Funding, LLC Q1 General.pdf ✓
#   [349/370] 1Rate, Inc Q1 General.pdf ✓
#   [350/370] Accelin Loans LLC Q1 General.pdf ✓
#   [351/370] ARBORETUM MORTGAGE CORPORATION_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [352/370] CHA Mortgage Company, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [353/370] American Intermutual Agency, Inc. Q1 General.pdf ✓
#   [354/370] American Financial Network, Inc._General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [355/370] American Financial Resources, Inc_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [356/370] Chu & Associates, Inc. Q1 General.pdf ✓
#   [357/370] All City Mortgage, LLC Q1 General.pdf ✓
#   [358/370] Consumer Portfolio Services, Inc. Q1 General.pdf ✓
#   [359/370] American Financial Resources, Inc. Q1 General.pdf ✓
#   [360/370] Central Coast Lending, Inc Q1 General.pdf ✓
#   [361/370] Bridgeview Finance LLC Q1 General.pdf ✓
#   [362/370] Advisors Mortgage Group, L.L.C. Q1 General.pdf ✓
#   [363/370] American Neighborhood Mortgage Acceptance Company LLC Q1 General.pdf ✓
#   [364/370] CGB Agri Financial Services, Inc. Q1 General.pdf ✓
#   [365/370] Chaos Home Loans LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [366/370] Buenaventura Inc. Q1 General.pdf ✓
#   [367/370] California Premier Services, Inc. Q1 General.pdf ✓
#   [368/370] Capital Alliance, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [369/370] Canopy Mortgage, LLC_General.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [370/370] Access Loans LLC Q1 General.pdf ✓
#
# [4/5] 处理FC文件...
#   [1/111] Caliber Home Loans, Inc. Q1 FC.pdf ✓
#   [2/111] American Interbanc Mortgage, LLC._FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [3/111] Aurora Financial Group, Inc. Q1 FC.pdf ✓
#   [4/111] Amerifirst Financial, Inc._FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [5/111] Atlantic Bay Mortgage Group, L.L.C. Q1 FC.pdf ✓
#   [6/111] BM REAL ESTATE SERVICES, INC. Q1 FC.pdf ✓
#   [7/111] American Pacific Mortgage Corporation_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [8/111] Cherry Creek Mortgage, LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [9/111] Angel Oak Home Loans LLC Q1 FC.pdf ✓
#   [10/111] CMG Mortgage, Inc. Q1 FC.pdf ✓
#   [11/111] Arvest Central Mortgage Company_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [12/111] AmeriHome Mortgage Company, LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [13/111] Cornerstone First Mortgage, Inc. Q1 FC.pdf ✓
#   [14/111] American Financial Resources, Inc._FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [15/111] Change Lending, LLC Q1 FC.pdf ✓
#   [16/111] Amerifirst Financial, Inc. Q1 FC.pdf ✓
#   [17/111] CountryPlace Mortgage, Ltd. Q1 FC.pdf ✓
#   [18/111] American Financial Network, Inc. Q1 FC.pdf ✓
#   [19/111] Academy Mortgage Corporation Q1 FC.pdf ✓
#   [20/111] Citimortgage, Inc. Q1 FC.pdf ✓
#   [21/111] American Financing Corporation Q1 FC.pdf ✓
#   [22/111] 21st Mortgage Corporation- Q1 FC.pdf ✓
#   [23/111] Caliber Home Loans, Inc._FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [24/111] AmRes Corporation Q1 FC.pdf ✓
#   [25/111] CalCon Mutual Mortgage LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [26/111] AmRes Corporation_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [27/111] Canopy Mortgage, LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [28/111] American Advisors Group Q1 FC.pdf ✓
#   [29/111] Angel Oak Home Loans LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [30/111] Angel Oak Mortgage Solutions LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [31/111] ACMC FINANCIAL CORP Q1 FC.pdf ✓
#   [32/111] Allied Mortgage Group, Inc. Q1 FC.pdf ✓
#   [33/111] Change Lending, LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [34/111] CalCon Mutual Mortgage LLC Q1 FC.pdf ✓
#   [35/111] CrossCountry Mortgage, LLC Q1 FC.pdf ✓
#   [36/111] American Financing Corporation_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [37/111] Blueleaf Lending, LLC Q2 FC.pdf ✓
#   [38/111] Castle & Cooke Mortgage, LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [39/111] American Finance House LARIBA Q1 FC.pdf ✓
#   [40/111] Canopy Mortgage, LLC Q1 FC.pdf ✓
#   [41/111] Cardinal Financial Company, Limited Partnership_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [42/111] Agape Mortgages, Inc. Q1 FC.pdf ✓
#   [43/111] CU Home Mortgage Solutions, LLC Q1 FC.pdf ✓
#   [44/111] Cherry Creek Mortgage, LLC Q1 FC.pdf ✓
#   [45/111] Bay Equity LLC Q1 FC.pdf ✓
#   [46/111] Arc Home LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [47/111] CU Home Mortgage Solutions, LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [48/111] American Advisors Group_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [49/111] Assurance Financial Group, L.L.C. Q1 FC.pdf ✓
#   [50/111] AmeriHome Mortgage Company, LLC Q1 FC.pdf ✓
#   [51/111] Best Capital Funding Q1 FC.pdf ✓
#   [52/111] Castle Mortgage Corporation_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [53/111] American Finance House LARIBA_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [54/111] ALAMEDA MORTGAGE CORPORATION Q1 FC.pdf ✓
#   [55/111] Amerisave Mortgage Corporation_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [56/111] American Pacific Mortgage Corporation Q1 FC.pdf ✓
#   [57/111] Broker Solutions, Inc._FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [58/111] Crescent Mortgage Company Q1 FC.pdf ✓
#   [59/111] Castle & Cooke Mortgage, LLC Q1 FC.pdf ✓
#   [60/111] Compu-Link Corporation Q1 FC.pdf ✓
#   [61/111] Amcap Mortgage, Ltd._FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [62/111] Alaska USA Mortgage Company, LLC Q1 FC.pdf ✓
#   [63/111] American Neighborhood Mortgage Acceptance Company LLC Q1 FC.pdf ✓
#   [64/111] AmWest Funding Corp._FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [65/111] Carrington Mortgage Services, LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [66/111] Credit Union Mortgage Association, Inc. Q1 FC.pdf ✓
#   [67/111] Churchill Mortgage Corporation_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [68/111] American Neighborhood Mortgage Acceptance Company LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [69/111] Ark-La-Tex Financial Services, LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [70/111] Amcap Mortgage, Ltd. Q1 FC.pdf ✓
#   [71/111] Churchill Mortgage Corporation Q1 FC.pdf ✓
#   [72/111] Contour Mortgage Corporation Q1 FC.pdf ✓
#   [73/111] 1ST 2ND MORTGAGE COMPANY OF N.J., INC. Q1 FC.pdf ✓
#   [74/111] Ark-La-Tex Financial Services, LLC Q1 FC.pdf ✓
#   [75/111] Compass Mortgage, Inc. Q1 FC.pdf ✓
#   [76/111] Cornerstone Home Lending, Inc. Q1 FC.pdf ✓
#   [77/111] 21st Mortgage Corporation Q1 FC.pdf ✓
#   [78/111] AmWest Funding Corp. Q1 FC.pdf ✓
#   [79/111] Broker Solutions, Inc. Q1 FC.pdf ✓
#   [80/111] Axia Financial, LLC Q1 FC.pdf ✓
#   [81/111] Arvest Central Mortgage Company Q1 FC.pdf ✓
#   [82/111] Better Mortgage Corporation Q1 FC.pdf ✓
#   [83/111] AmeriNational Community Services, LLC Q1 FC.pdf ✓
#   [84/111] American Portfolio Mortgage Corporation_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [85/111] Celebrity Home Loans, LLC Q1 FC.pdf ✓
#   [86/111] Amerisave Mortgage Corporation Q1 FC.pdf ✓
#   [87/111] Cooper Mortgage, Inc. Q1 FC.pdf ✓
#   [88/111] AmeriFirst Home Improvement Finance, LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [89/111] Angel Oak Mortgage Solutions LLC Q1 FC.pdf ✓
#   [90/111] Bay-Valley Mortgage Group Q1 FC.pdf ✓
#   [91/111] Community Mortgage Funding, LLC Q1 FC.pdf ✓
#   [92/111] Celebrity Home Loans, LLC_FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [93/111] American Internet Mortgage, Inc._FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [94/111] Carrington Mortgage Services, LLC Q1 FC.pdf ✓
#   [95/111] CarsDirect Mortgage Services, Inc. Q1 FC.pdf ✓
#   [96/111] Advisors Mortgage Group, L.L.C. Q1 FC.pdf ✓
#   [97/111] Cardinal Financial Company, Limited Partnership Q1 FC.pdf ✓
#   [98/111] Community Loan Servicing, LLC Q1 FC.pdf ✓
#   [99/111] Allied Mortgage Group, Inc._FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [100/111] American Portfolio Mortgage Corporation Q1 FC.pdf ✓
#   [101/111] Access Capital Group, Inc. Q1 FC.pdf ✓
#   [102/111] AmeriFirst Home Improvement Finance, LLC Q1 FC.pdf ✓
#   [103/111] American Internet Mortgage, Inc. Q1 FC.pdf ✓
#   [104/111] Arc Home LLC Q1 FC.pdf ✓
#   [105/111] CIS Financial Services, Inc. Q1 FC.pdf ✓
#   [106/111] Castle Mortgage Corporation Q1 FC.pdf ✓
#   [107/111] CMC Funding, Inc. Q1 FC.pdf ✓
#   [108/111] American Financial Resources, Inc. Q1 FC.pdf ✓
#   [109/111] American Financial Network, Inc._FC.pdf ✗ 跳过
#       原因: PDF存在编码问题，无法读取
#   [110/111] Blueleaf Lending, LLC Q1 FC.pdf ✓
#   [111/111] All Western Mortgage, Inc. Q1 FC.pdf ✓
#
# [5/5] 生成CSV文件...
#   ✓ CreditLine_output.csv (434 行)
#   ✓ Service_output.csv (260 行)
#   ✓ FC_output.csv (72 行)
#
# ============================================================
# 处理完成！
# ============================================================
# 成功处理: 341 / 481 个文件
#   - General: 266 / 370
#   - FC: 75 / 111
#
# ⚠️  跳过 140 个文件:
#   - American First Lending Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Advisors Group_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Choice Lending Corp_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Change Lending, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Chelgren and Associates, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Broker Services, Inc_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Caliber Home Loans, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Amcap Mortgage, Ltd._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Amerisave Mortgage Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - CUW Solutions, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Caliver Beach Mortgage, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Campos Financial Corp._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - AmeriCredit Financial Services, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Capital M Lending, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - California Premier Services, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - AmNet ESOP Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Angel Oak Home Loans LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Cascade Northern Mortgage Inc_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Chelsea Investment Group, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Cascade Residential Mortgage, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - AMERIQUEST FUNDING, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Apex Mortgage, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Amos Financial LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Heritage Capital, LP_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Archstone Home Mortgage, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Neighborhood Mortgage Acceptance Company LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Finance House LARIBA_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - AmRes Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - AMERICAN MORTGAGE INC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Internet Mortgage, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Wholesale Loans LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - CGB Agri Financial Services, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Catlin Capital, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Central Mortgage Funding, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Celebrity Home Loans, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Ark-La-Tex Financial Services, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - America Home Mortgage Corporation, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Central Coast Lending, Inc_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Intermutual Agency, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Allied Servicing Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Angel Oak Mortgage Solutions LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Altisource Fulfillment Operations, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Cascade Home Sales, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Calculated Risk Analytics LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Financing Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Cherry Creek Mortgage, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Allied Mortgage Group, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Arc Home LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Castle & Cooke Mortgage, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Catalyst Mortgage_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Pacific Mortgage Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Amerifirst Financial, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - AmeriHome Mortgage Company, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - CU Home Mortgage Solutions, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Cascade Premier Mortgage, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - AmWest Funding Corp._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Churchill Mortgage Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Portfolio Mortgage Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Chu & Associates, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Castle Mortgage Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Prime Lending, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - AmeriFirst Home Improvement Finance, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Heritage Lending, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Cascade Equity Group Inc_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Button Finance, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Budget Mortgage Corp._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Mortgage and Insurance Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Interbanc Mortgage, LLC._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - CalCon Mutual Mortgage LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Aslan Home Lending Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Altamont Mortgage Funding, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Nationwide Mortgage Company, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Cascade Valley Mortgage LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Broker Solutions, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - CEL Lending LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Anderson, Erick B._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Cuervo, Michael Craig_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Casa Financial Services, Inc_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Chattel Funding, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - AmericaWest Financial, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - CentralBanc Mortgage Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - C & E Financial Group, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Chicago Financial Services, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Arvest Central Mortgage Company_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Cardinal Financial Company, Limited Partnership_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Arete Mortgage NW, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Arcus Lending Inc_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Central Group Mortgage LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Carrington Mortgage Services, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Buenaventura Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - America Mortgage, L.L.C._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - C2 Financial Corporation_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Cascade Lending Group LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Certain Lending, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Capstone Direct, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - California Mortgage Advisors, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Assurance Financial Group, L.L.C.Q1 General.pdf
#     原因: PDF存在编码问题，无法读取
#   - ARBORETUM MORTGAGE CORPORATION_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - CHA Mortgage Company, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Financial Network, Inc._General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Financial Resources, Inc_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Chaos Home Loans LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Capital Alliance, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - Canopy Mortgage, LLC_General.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Interbanc Mortgage, LLC._FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Amerifirst Financial, Inc._FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Pacific Mortgage Corporation_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Cherry Creek Mortgage, LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Arvest Central Mortgage Company_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - AmeriHome Mortgage Company, LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Financial Resources, Inc._FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Caliber Home Loans, Inc._FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - CalCon Mutual Mortgage LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - AmRes Corporation_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Canopy Mortgage, LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Angel Oak Home Loans LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Angel Oak Mortgage Solutions LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Change Lending, LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Financing Corporation_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Castle & Cooke Mortgage, LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Cardinal Financial Company, Limited Partnership_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Arc Home LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - CU Home Mortgage Solutions, LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Advisors Group_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Castle Mortgage Corporation_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Finance House LARIBA_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Amerisave Mortgage Corporation_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Broker Solutions, Inc._FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Amcap Mortgage, Ltd._FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - AmWest Funding Corp._FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Carrington Mortgage Services, LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Churchill Mortgage Corporation_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Neighborhood Mortgage Acceptance Company LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Ark-La-Tex Financial Services, LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Portfolio Mortgage Corporation_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - AmeriFirst Home Improvement Finance, LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Celebrity Home Loans, LLC_FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Internet Mortgage, Inc._FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - Allied Mortgage Group, Inc._FC.pdf
#     原因: PDF存在编码问题，无法读取
#   - American Financial Network, Inc._FC.pdf
#     原因: PDF存在编码问题，无法读取
#
# 跳过文件列表已保存: ./skipped_files.csv
